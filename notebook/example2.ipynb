# %%
from sklearn.model_selection import StratifiedShuffleSplit
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Projects\ML_PROJECT\Machine_learning_Project1\venv\lib\site-packages\scipy-1.9.0rc1-py3.8-win-amd64.egg\scipy\__init__.py:201, in __getattr__(name)
#     200 try:
# --> 201     return globals()[name]
#     202 except KeyError:
#
# KeyError: '_lib'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\Projects\ML_PROJECT\Machine_learning_Project1\notebook\example2.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Projects/ML_PROJECT/Machine_learning_Project1/notebook/example2.ipynb#ch0000000?line=0'>1</a> from sklearn.model_selection import StratifiedShuffleSplit
#
# ...
